# %% [markdown]
# # OOPS

# %% [markdown]
# 1. What s objet-oriented program(oop)?
#  -  oop is the programming paradigm or style of organizing code which is majorly based on classes and objects.
#
#  2. What is a class in oop?
#   -  class in oop is a blueprint or template for creating object.
#
#   3. What is an object in oop?
#    - In oop object is a self contained unit that bundles together data(attributes) and behaviour(methods), serving as a specific instance of a class.
#    4. What is the difference between abstraction and encapsulation?
#    - Abstraction shows only important details and hides the internal working, while encapsulation wraps data and methods together and protects the data from misuse.
#    5. What are dunder method in python?
#   - special methods with double underscores(e.g.__init__) used to define class behaviour.
#   6. Explain the concept of inheritance in OOP.
#   - Inheritance allows a class to acquire properties and methods of another class.
#   7. What is polymorphism in oop?
#   -  Polymorphism means one function or method behaves differently for different objects.
#   8. How is encapsulation achieved in python?
#   -  By using classes and access specifiers(public, protected,private variable).
#   9. What is a constructor in Python?
#   -  A constructor is  __init__() method used to initialize object data.
#   10. What are class and static methods in Pythn?
#   -  Class methods use @classmethod and @staticmethod and dont access class or object data.
#   11. What is method overloading in Python?
#   -  Defining methods with the same name but different parameters (handled using default arguments).
#   12.  What is method overriding in OOP?
#   -  Redefining a parent class method in a child class.
#   13. What is a property decorator in Python?
#   -  It allows a method to be accessed like an attribute.
#   14. Why is polymorphism important in oop?
#   -  It improves flexibility, reusability, and code simplicity.
#   15. What is an abstract class in Python?
#   -  A class that cannot be instantiated and contains abstrct method.
#   16. What are the advantages of OOP?
#   -  code reusability, security, easy maintenance, and modularity.
#   17.  Difference between class variable and instance variable?
#   - Class variable is shared by all objects;instance variable is unique to each object.
#   18. What is multiple inheritance in Python?
#   - A class inheriting from more than one parent class.
#   19.  Purpose of __str__() and __repr__() methods?
#   - __str__() gives readable output;__repr__() gives developer-friendly output.
#   20. Significance of super() function in Python?
#   - Used to call parent class methods.
#   21. Significance of of __call__() method in Python?
#   - Allows n object to be called like a function.
#   22. Difference between static method and class method?
#   - Static method does not allow class data; class method accesses class data.
#   23. How does polymorphism work with inheritance?
#   - Child class method override parent class method.
#   24. What is method chaining in Python OOP?
#   - Calling multiple methods using the same object sequentially.
#   25. Purpose of __del__() method in Python?
#   - It destroys the object frees memory.

# %%
#Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark".
class Animal:
  def speak(self):
    print("Animals makes a sound.")

class Dog(Animal):
  def speak(self):
    print("Bark!")

dog = Dog()
dog.speak() #Bark
# Out:
# Bark!

# %%
#Write a program to create an abstract class shape with a method area().Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod
class Shape(ABC):
   @abstractmethod
   def area(self):
      pass

class Circle(Shape):
      def __init__(self, radius):
       self.radius = radius

      def area(self):
       return 3.14 * self.radius ** 2
class Rectangle(Shape):
      def __init__(self, length, width):
        self.length = length; self.width = width
      def area(self):
        return self.length*self.width
circle = Circle(5); print(circle.area())
# Out:
# 78.5

# %%
# Implement a multi-level inheritance scenario where a class vehicle has an attribute type.Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
  def __init__(self, type):
    self.type = type
class Car(Vehicle):
  def __init__(self, type, fuel):
    super().__init__(type)
    self.fuel = fuel
class ElectricCar(Car):
  def __init__(self, type, fuel, battery):
    super().__init__(type, fuel)
    self.battery = battery
ev = ElectricCar("car", "electric", "40KWh")

# %%
#Demonstrate polymorphism by creating a base class Bird with a method fly().  create two derived classes Sparrow and Penguin that override the fly() method.

class Bird:
  def fly(self):
    pass
class Sparrow(Bird):
  def fly(self):
    return "Sparrow flies hing."
class Penguin(Bird):
  def fly(self):
    return "Penguin can't fly."

birds = [Sparrow(), Penguin()]
for bird in birds:
   print(bird.fly())
# Out:
# Sparrow flies hing.
# Penguin can't fly.

# %%
# Write a program to demonstrate Encapsulation by creating class Bankaccount with private attributes balance and methods to deposit, withdraw, check balance.

class Bankaccount:
  def __init__(self, balance):
    self.__balance = balance
  def deposit(self, amount):
    self.__balance += amount
  def withdraw(self, amount):
    if amount <= self.__balance:
      self.__balance -= amount
  def check_balance(self):
    return self.__balance

acc = Bankaccount(1000); acc.deposit(500); print(acc.check_balance())
# Out:
# 1500

# %%
# Demonstrate runtime polymorphism using a method play() in a base class instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
  def play(self):
    pass
class Guitar(Instrument):
  def play(self):
    return "playing guitar."
class Piano(Instrument):
  def play(self):
     return "playing piano."

instruments = [Guitar(), Piano()]
for inst in instruments:
   print(inst.play())
# Out:
# playing guitar.
# playing piano.

# %%
# Ceate a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
  @staticmethod
  def subtract_numbers(a, b):
    return a - b

  def add_numbers(self, a, b):
    return a + b

math = MathOperations()
print(math.add_numbers(5, 3))
print(MathOperations.subtract_numbers(5, 3))
# Out:
# 8
# 2

# %%
# Implement a class Person with a class method to count the total number of persons created.

class Person:
  total_persons = 0
  def __init__(self, name):
    self.name = name
    Person.total_persons += 1
  @classmethod
  def count_persons(cls):
    return cls.total_persons
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print(Person.count_persons())
# Out:
# 3

# %%
# Write a class Fraction with attributes numerator and denominator.override str method to display the fraction as "numerator/denominator".

class Fraction:
  def __init__(self, numerator, denominator):
     self.numerator = numerator
     self.denominator = denominator
  def __str__(self):
     return f"{self.numerator}/{self.denominator}"

f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %%
# Demonstrate operator overloading by creting class Vector and overriding the add method to add two vectors.

class Vector:
  def __init__(self, x, y):
    self.x = x; self.y = y
  def __add__(self, other):
    return Vector(self.x + other.x, self.y + other.y)
  def __str__(self):
    return f"({self.x}, {self.y})"

v1 = Vector(1, 2); v2 = Vector(3, 4)
print(v1 + v2)
# Out:
# (4, 6)

# %%
# Create a class Person with attributes name and age. add a method greet()  that prints "Hello, my name is {name}, and iam {age} years old".

class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age
  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} yers old ")

p = Person("Rohaan", 27)
p.greet()
# Out:
# Hello, my name is Rohaan and I am 27 yers old

# %%
# Implement a class Student with attributes name and grades.create a method average_grade() to compute the average grades.

class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades
  def average_grade(self):
    return sum(self.grades)/ len(self.grades)

s = Student("Bina", [85, 90, 78])
print(s.average_grade())
# Out:
# 84.33333333333333

# %%
# Create a class Rectangle with method set_dimensions() to set dimension and area() to calculate the area.

class Rectangle:
  def set_dimensions(self, length, width):
    self.length = length; self.width = width
  def area(self):
    return self.length * self.width

rect = Rectangle(); rect.set_dimensions(4, 5)
print(rect.area())
# Out:
# 20

# %%
# Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
  def __init__(self, hours_worked, hourly_rate):
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate

class Manager(Employee):
  def __init__(self, hours_worked, hourly_rate, bonus):
    super().__init__(hours_worked, hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    base_salary = super().calculate_salary()
    return base_salary + self.bonus

emp = Employee(160, 50)
print(emp.calculate_salary())

mgr = Manager(160, 50, 1000)
print(mgr.calculate_salary())
# Out:
# 8000
# 9000

# %%
# Create a class Product with attributes name, price and quantity. Implement a method total_price that calcilates the total price of the product.

class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

prod = Product("Laptop", 50000, 2)
print(prod.total_price())
# Out:
# 100000

# %%
# Create a class Animal with an abstract method sound() and create two derived classes Cow and Sheep that implement the method sound().

from abc import ABC, abstractmethod
class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    return "Moo"

class Sheep(Animal):
  def sound(self):
    return "Baa"

cow = Cow()
print(cow.sound())

sheep = Sheep()
print(sheep.sound())
# Out:
# Moo
# Baa

# %%
# Create a class Book with attributes title, authour and year_published.Add a method get_book_info() that returns a formatted string with book detail's.

class Book:
  def __init__(self, title, authour, year_published):
    self.title = title
    self.authour = authour
    self.year_published =year_published

  def get_book_info(self):
    return f"'{self.title}' by {self.authour}, published in {self.year_published}"

book =Book("1984", "George Orwell", 1949)
print(book.get_book_info())
# Out:
# '1984' by George Orwell, published in 1949

# %%
# Create a class House with attributes address and price.Create a derived class Mansion that adds an attribute number of rooms.

class House:
  def __init__(self, address, price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms

house = House("06 Rd", 5000000)
mansion = Mansion("76 pn", 6000000, 22)
print(mansion.number_of_rooms)
# Out:
# 22
